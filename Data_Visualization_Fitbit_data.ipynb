# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as snr

# %%
new_data=pd.read_csv("/content/FitBit data.csv")

# %%
new_data.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
data=new_data.drop(['Id', 'ActivityDate'], axis=1)

# %%
data.head()
# Out:
#    TotalSteps  TotalDistance  TrackerDistance  LoggedActivitiesDistance  \
# 0       11004           7.11             7.11                       0.0
# 1       17609          11.55            11.55                       0.0
# 2       12736           8.53             8.53                       0.0
# 3       13231           8.93             8.93                       0.0
# 4       12041           7.85             7.85                       0.0
#
#    VeryActiveDistance  ModeratelyActiveDistance  LightActiveDistance  \
# 0                2.57                      0.46                 4.07
# 1                6.92                      0.73                 3.91
# 2                4.66                      0.16                 3.71
# 3                3.19                      0.79                 4.95
# 4                2.16                      1.09                 4.61
#
#    SedentaryActiveDistance  VeryActiveMinutes  FairlyActiveMinutes  \
# ...

# %%
#line Graph
ax=data.plot(figsize=(20,10), title='FitBit Datase')
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
# there is too much of fluctuation in Total Steps, Lightly active minutes looks stable.

# %%
data['LightlyActiveMinutes'].diff().plot(kind='hist', bins=200)

# %%
data['TotalSteps'].diff().plot(kind='hist', bins=300)

# %%
data.iloc[0:5].plot(kind='bar')

# %%
data.iloc[5].plot(kind='bar')

# %%
data.iloc[0].plot.pie(figsize=(10,10), fontsize=15, autopct='%.2f')

# %%
data.plot.scatter(x='TrackerDistance', y='LightActiveDistance')

# %%
# The variation of lightActiveDistance is linear wrt TrackerDistance

# %%
data.plot.scatter(x='TrackerDistance', y='LightActiveDistance', c='FairlyActiveMinutes')

# %%
#boxplot
snr.catplot(x='TotalSteps', y='VeryActiveDistance', hue='FairlyActiveMinutes', kind='box', data=data)
